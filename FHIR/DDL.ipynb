# %%
# %sql
CREATE CATALOG IF NOT EXISTS fhir_catalog;

USE CATALOG fhir_catalog;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE SCHEMA IF NOT EXISTS fhir_catalog.raw;
CREATE SCHEMA IF NOT EXISTS fhir_catalog.bronze;

CREATE VOLUME IF NOT EXISTS fhir_catalog.raw.fhir_raw_vol;
CREATE VOLUME IF NOT EXISTS fhir_catalog.bronze.fhir_bronze_vol;

# %%
# %sql
-- DROP VOLUME IF EXISTS cg_fhir;
DROP CATALOG IF EXISTS cg_fhir;
-- SHOW SCHEMAS IN cg_fhir;
-- DROP SCHEMA cg_fhir.information_schema CASCADE;

-- drop schema if exists default;
-- drop schema if exists information_schema;

# %%
# %sql
CREATE TABLE IF NOT EXISTS fhir_catalog.bronze.page_tracker (
  resource STRING,
  last_page INT
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS fhir_catalog.silver.watermark_tracker (
  resource STRING,
  last_processed_ts STRING
);

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS fhir_catalog.audit;

# %%
# %sql
CREATE TABLE IF NOT EXISTS fhir_catalog.audit.bronze_log (
    run_id STRING,
    resource STRING,
    load_date STRING,
    status STRING,
    start_time TIMESTAMP,
    end_time TIMESTAMP,
    record_count BIGINT,
    message STRING
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS fhir_catalog.audit.silver_log (
    run_id STRING,
    resource STRING,
    status STRING,
    start_time TIMESTAMP,
    end_time TIMESTAMP,
    record_count BIGINT,
    message STRING
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS fhir_catalog.audit.gold_log (
    run_id STRING,
    process STRING,
    status STRING,
    start_time TIMESTAMP,
    end_time TIMESTAMP,
    record_count BIGINT,
    message STRING
);
